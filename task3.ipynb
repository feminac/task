# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
titanic=pd.read_csv(r'D:\data analytics\pandas_docs\titanic_file.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.catplot(x='Sex',kind='count',palette='rocket_r',data=titanic,hue='Pclass')

# %%
grouped_data=titanic.groupby('Pclass').count().sum()

# %%
total_group = titanic.groupby(['Pclass','Sex']).size().reset_index(name='Count')
total_group
# Out:
#    Pclass     Sex  Count
# 0       1  female     94
# 1       1    male    122
# 2       2  female     76
# 3       2    male    108
# 4       3  female    144
# 5       3    male    347

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.catplot(x='Age',y='Sex',kind='strip',palette='rocket_r',data=titanic)
# Out:
# C:\Users\femif\AppData\Local\Temp\ipykernel_3108\3669555617.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='Age',y='Sex',kind='strip',palette='rocket_r',data=titanic)

# %%
sns.catplot(x='Age',y='Sex',kind='violin',hue='Pclass',data=titanic,palette='rocket_r')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
cs=pd.read_csv(r'C:\Users\femif\Downloads\stack-overflow-developer-survey-2019\survey_results_public.csv')
cs
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
sns.catplot(x='Age',y='Gender',kind='strip',hue='Sexuality',data=cs,palette='rocket_r')
# Out:
# C:\Users\femif\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# .there are more males

# %%
sns.relplot(x='Dependents',y='Employment',hue='Sexuality',col='Student',data=cs,col_wrap=5)

# %%
tips = pd.read_csv(r'C:\Users\femif\Downloads\tips.csv.xls')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='total_bill',y='sex',kind='strip',hue='smoker',data=tips)

# %%
sns.relplot(x='day',y='tip',hue='time',col='size',data=tips,col_wrap=3)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='day',hue='size')

# %%
data_iris = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.catplot(x='sepal_length',y='species',kind='violin',data=data_iris)

# %%
sns.catplot(x='sepal_width',y='petal_length',kind='strip',hue='species',data=data_iris)
