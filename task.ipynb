# %%
import pandas as pd

# %%
book=pd.read_csv('Book1.csv')
book
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 book=pd.read_csv('Book1.csv')
#       2 book
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
pd.read_csv('demo1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12    file

# %%
book=pd.read_excel(r'C:\Users\femif\OneDrive\Desktop\t3\Book1.xlsx')
book
# Out:
#        name  age group
# 0      hbhs   33    a+
# 1     knjsx   65    o+
# 2  sxbgyhge   54    a+
# 3   nsbxhxs   67    b+

# %%
import pandas as pd

# %%
a=pd.read_excel(r'C:\Users\femif\OneDrive\Desktop\TimeCard1.xlsx')
a
# Out:
#     Unnamed: 0            Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0          NaN                   NaN                  NaN                 NaN
# 1          NaN                   NaN                  NaN                 NaN
# 2          NaN                   NaN                  NaN                 NaN
# 3          NaN                   NaN                  NaN                 NaN
# 4          NaN                   NaN                  NaN                 NaN
# 5          NaN              Employee               femina                 NaN
# 6          NaN                   NaN                  NaN                 NaN
# 7          NaN      [Street Address]             vatakara                 NaN
# 8          NaN                   NaN                  NaN                 NaN
# 9          NaN           [Address 2]              mnbsxky                 NaN
# 10         NaN                   NaN                  NaN                 NaN
# ...

# %%
a[:5]
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Time Card
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4    gyuwsyq       NaN

# %%
b=pd.read_table(r'C:\Users\femif\OneDrive\Documents\femina.task3.txt')
b
# Out:
#                                #1
# 0                              a)
# 1                             i=1
# 2                    while i<=10:
# 3                      if i%2==0:
# 4                        print(i)
# ..                            ...
# 56                            i=0
# 57                   while i<=10:
# 58                        sum=i*a
# 59         print(i,"*",a,"=",sum)
# 60                          i=i+1
#
# [61 rows x 1 columns]

# %%
ph=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\ph.py')
ph
# Out:
#                 #basicprogramming
# 0                print("hello"+4)
# 1                   print("hi"*5)
# 2                 print("hi"+5.7)
# 3                 print("hi"*5.7)
# 4           #string concatination
# 5   #print("hello"+" * "+"world")
# 6              #print(int("3")+4)
# 7       #print(int("4")+int("3"))
# 8         #print("hello \nworld")
# 9        "print(mothers's world")
# 10                    print(2**5)
# 11                print(4**(1/2))
# 12              print(4%2)#modulo
# 13                     print(5/3)
# 14  print(5//3) #floor divison"""

# %%
li=pd.read_table(r'C:\Users\femif\OneDrive\Documents\list1.txt')
li.head()
# Out:
#           a=["hello",67,"yellow",7,[4,5,6],9,"blue"]
# 0  "print(a[0])\r\nprint(a[1])\r\nprint(a[2])\r\n...
# 1                                           print(a)
# 2                                        a.append(5)
# 3                                           print(a)
# 4                                a.insert(4,"black")

# %%
demo=pd.read_table('D:\data analytics\pandas_docs\demo3.txt')
demo
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
demo(columns['number','a'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 demo(columns['number','a'])
#
# NameError: name 'columns' is not defined

# %%
pd.DataFrame(demo,columns=['a','b','c'])
# Out:
#     a   b   c
# 0 NaN NaN NaN
# 1 NaN NaN NaN
# 2 NaN NaN NaN
# 3 NaN NaN NaN

# %%
deff=pd.read_csv('D:\data analytics\diff_sep.csv')
deff
# Out:
#                                                   #Name#Sex#Age
# 0#Braund                              Mr. Owen Harris#male#22.0
# 1#Cumings      Mrs. John Bradley (Florence Briggs Thayer)#fe...
# 2#Heikkinen                             Miss. Laina#female#26.0
# 3#Futrelle       Mrs. Jacques Heath (Lily May Peel)#female#35.0
# 4#Allen                             Mr. William Henry#male#35.0
# 5#Moran                                         Mr. James#male#
# 6#McCarthy                              Mr. Timothy J#male#54.0
# 7#Palsson                        Master. Gosta Leonard#male#2.0
# 8#Johnson      Mrs. Oscar W (Elisabeth Vilhelmina Berg)#fema...
# 9#Nasser                Mrs. Nicholas (Adele Achem)#female#14.0
# 10#Sandstrom                    Miss. Marguerite Rut#female#4.0

# %%
string=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\t3\string_functions.py')
string
# Out:
#                       #string function
# 0   #join-->separotor.join(list,tuple)
# 1          "a=[welcome","to","python"]
# 2                    print("".join(a))
# 3          a=("welcome","to","python")
# 4                    print("".join(a))
# ..                                 ...
# 64               c="python is awesome"
# 65                    print(c.upper())
# 66                              #lower
# 67               V="PYTHON IS AWESOME"
# 68                 print(V.lower())"""
#
# [69 rows x 1 columns]

# %%
tup=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\t3\tuple.py')
tup
# Out:
#                                               #tupple
# 0   tuple1=("apple","yellow","red","red",76,8,True...
# 1   "print(tuple1)\r\nprint(type(tuple1))\r\n\r\na...
# 2                                              #count
# 3                          print(tuple1.count("red"))
# 4                                                 #in
# 5                            print("apple" in tuple1)
# 6                             print("gray" in tuple1)
# 7                                                #not
# 8                         print("gray" not in tuple1)
# 9                        print("apple" not in tuple1)
# 10                                      b=("python",)
# 11                                           print(b)
# 12                                      x="a","b","d"
# 13                                     print(type(x))
# 14                                        y=1,2,3,4,5
# 15                                         print(x+y)
# ...

# %%
boolean=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\basic\boolean logic operator\boolean2.py')
boolean
# Out:
#                             #boolean logical operator
# 0                                       #and operator
# 1   "print(1==1 and 2==2)\r\nprint(2==4 and 4==4)\...
# 2                         "x=int(input(1st number:"))
# 3                         y=int(input("2nd number:"))
# 4                         z=int(input("3rd number:"))
# 5                                     if x>y and x>z:
# 6                    print("greater element is***",x)
# 7                                   elif y>x and y>z:
# 8                    print("greater element is###",y)
# 9                                               else:
# 10                print("greater element is$$$",z)"""
# 11                                      #not operator
# 12                                     print(not 7>4)
# 13                                    print(not 3==9)

# %%
whil=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\basic\boolean logic operator\while.py')
whil
# Out:
#                                           #while loop
# 0            "i=5\r\nwhile i<=5:\r\n    print(hello")
# 1                                            i=i+1"""
# 2   "i=1\r\nwhile i<=100:\r\n    print(i)\r\n    i...
# 3                                              #break
# 4                      "while True:\r\n    print(hi")
# 5                                            break"""
# 6   "i=1\r\nwhile i<=25:\r\n    print(i)\r\n    if...
# 7   "i=2\r\nwhile True:\r\n    print(i)\r\n    if ...
# 8   "i=2\r\nwhile i<=10:\r\n    if i%2==0:\r\n    ...
# 9                   n=int(input("enter the number:"))
# 10                                                i=1
# 11                                        while i<=5:
# 12                             print(i,"*",n,"=",i*n)
# 13                                              i=i+1
# 14                                          #continue
# 15  "i=1\r\nwhile i<=10:\r\n    i=i+1\r\n    if i=...
# ...

# %%
analytics=pd.read_table(r'C:\analytics.ipynb')
analytics
# Out:
#                                              {
# 0                                   "cells": [
# 1                                            {
# 2                         "cell_type": "code",
# 3                     "execution_count": null,
# 4                            "id": "70096746",
# 5                              "metadata": {},
# 6                               "outputs": [],
# 7                                 "source": []
# 8                                            }
# 9                                           ],
# 10                               "metadata": {
# 11                             "kernelspec": {
# 12     "display_name": "Python 3 (ipykernel)",
# 13                       "language": "python",
# 14                           "name": "python3"
# 15                                          },
# 16                          "language_info": {
# 17                        "codemirror_mode": {
# 18                          "name": "ipython",
# ...

# %%
demo=pd.read_csv('C:\demo3.csv')
demo
# Out:
#                A         B         C
# 0  aaa -0.264438 -1.026059 -0.619500
# 1  bbb  0.927272  0.302904 -0.032399
# 2  ccc -0.264273 -0.386314 -0.217601
# 3  ddd -0.871858 -0.348382  1.100491

# %%
book4=pd.read_excel(r'D:\book4.xlsx')
book4
# Out:
#     school district       state
# 0  memunda     kzkd      kerala
# 1  puthoor     kzkd      kerala
# 2   bavann     ghsd  karanadaka
# 3     nbhd    jgdyw       okolw
# 4     jheu   jiudhw       wdwlk

# %%
sett=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\t3\set.py')
sett
# Out:
#                                                  #set
# 0           a={"apple",65,"red","red",9,7.8,"yellow"}
# 1   "print(a)\r\nprint(type(a))\r\nc=set()#empty s...
# 2                                            print(a)
# 3   a.add(("e","f","g"))#adding function many time...
# 4                                            print(a)
# 5                                        print(len(a)
# 6              #update(multiple data stored at a tme)
# 7                               a.update("a","b","c")
# 8                                            print(a)
# 9                                             #delete
# 10                                            #remove
# 11                                  a.remove("apple")
# 12                                           print(a)
# 13                                           #discard
# 14                                a.discard("yellow")
# 15                                           print(a)
# ...

# %%
lambdaa=pd.read_table(r'C:\Users\femif\OneDrive\Desktop\t3\lamda.py')
lambdaa.head(7)
# Out:
#                                       #lamda functon
# 0  "def fun(x):\r\n    print(x+5)\r\n    print(x*...
# 1                                                b()
# 2                  c=lambda name:print("hello",name)
# 3                                            c("hi")
# 4                                   x=lambda a,b:a+b
# 5                          print("result is",x(3,6))
# 6                               x=lambda a,b,c:a+b+c

# %%
f=pd.read_table(r'C:\Users\femif\OneDrive\Documents\femina.txt')
f
# Out:
#    "a=int(input(enter the number:"))
# 0                         if a%2==0:
# 1            print("number is even")
# 2                              else:
# 3          print("number is odd")"""
# 4     "a=int(input(enter the age:"))
# ..                               ...
# 59                     print("fair")
# 60             elif n<=65 and n>=55:
# 61                     print("good")
# 62                             else:
# 63               print("exelent")"""
#
# [64 rows x 1 columns]

# %%
import pandas as pd

# %%
data={
    'student':["amit","dravid","kumar"],
    'rank':[1,2,3],
    'marks':[78,90,86]
}
res=pd.DataFrame(data)
print("Student Record\n\n",res)
# Out:
# Student Record
#
#    student  rank  marks
# 0    amit     1     78
# 1  dravid     2     90
# 2   kumar     3     86

# %%
mark=pd.read_table(r'C:\Users\femif\OneDrive\Documents\Untitled.txt')
mark
# Out:
#      student  rank  marks
# 0  0    amit     1     78
# 1  1  dravid     2     90
# 2  2   kumar     3     86

# %%
import pandas as pd

# %%
book4=pd.read_excel(r'D:\book4.xlsx')
book4
# Out:
#     school district       state
# 0  memunda     kzkd      kerala
# 1  puthoor     kzkd      kerala
# 2   bavann     ghsd  karanadaka
# 3     nbhd    jgdyw       okolw
# 4     jheu   jiudhw       wdwlk

# %%
book3=pd.fillna('hello')
book3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 book3=pd.fillna('hello')
#       2 book3
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'fillna'

# %%
book4=pd.read_excel(r'D:\book4.xlsx')
book4
# Out:
#     school district       state
# 0  memunda     kzkd      kerala
# 1  puthoor     kzkd         NaN
# 2   bavann     ghsd  karanadaka
# 3     nbhd      NaN       okolw
# 4     jheu   jiudhw       wdwlk

# %%
book4.fillna('hello')
# Out:
#     school district       state
# 0  memunda     kzkd      kerala
# 1  puthoor     kzkd       hello
# 2   bavann     ghsd  karanadaka
# 3     nbhd    hello       okolw
# 4     jheu   jiudhw       wdwlk

# %%
book4.dropna
# Out:
# <bound method DataFrame.dropna of     school district       state
# 0  memunda     kzkd      kerala
# 1  puthoor     kzkd         NaN
# 2   bavann     ghsd  karanadaka
# 3     nbhd      NaN       okolw
# 4     jheu   jiudhw       wdwlk>

# %%
"welcome to kerala"
# Out:
# 'welcome to kerala'

# %%
a=3+4
a
# Out:
# 7

# %%
a=4
b=5
while a>b:
    print("true")
else:
    print("false")
# Out:
# false

# %%
import pandas as pd

# %%
a=int(input("enter a first number:"))
b=int(input("enter a second number:"))
print("1.add\n,2.multiplication\n,3.substraction\n,4.division\n")
choice=int(input("enter a choice:"))
if choice==1:
    print(a+b)
elif choice==2:
    print(a*b)
elif choice==3:
    print(a-b)21
elif choice==4:
    print(a/b)
else:
    print("invalid")
# Out:
#   Cell In[4], line 11
#     elif choice==4
#                   ^
# SyntaxError: expected ':'

# %%
list=[2,3,4,5,6]
len(list)
# Out:
# 5

# %%
import pandas as pd

# %%
data={
    'country':['india','beazil','belgium'],
    'capital':['newdelhi','barsilia','brussels'],
    'population':[1223,34545,3445567]
}
data1=pd.DataFrame(data)
data1
# Out:
#    country   capital  population
# 0    india  newdelhi        1223
# 1   beazil  barsilia       34545
# 2  belgium  brussels     3445567

# %%
data1.drop('capital',axis=1)
# Out:
#    country  population
# 0    india        1223
# 1   beazil       34545
# 2  belgium     3445567

# %%
data1.sort_index()
# Out:
#    country   capital  population
# 0    india  newdelhi        1223
# 1   beazil  barsilia       34545
# 2  belgium  brussels     3445567

# %%
data1.sort_values(by='country')
# Out:
#    country   capital  population
# 1   beazil  barsilia       34545
# 2  belgium  brussels     3445567
# 0    india  newdelhi        1223

# %%
data1.rank()
# Out:
#    country  capital  population
# 0      3.0      3.0         1.0
# 1      1.0      1.0         2.0
# 2      2.0      2.0         3.0

# %%
data1[1:2]
# Out:
#   country   capital  population
# 1  beazil  barsilia       34545

# %%
data1.iloc[[0],[0]]
# Out:
#   country
# 0   india
